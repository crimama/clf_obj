# %%
https://github.com/ultralytics/yolov5/issues/251

# %% [markdown]
# #torch to onnx

# %%
# %cd /content/
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v6.1-250-g6adc53b Python-3.7.13 torch-1.11.0+cu113 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 38.6/225.9 GB disk)

# %%
# !cp '/content/drive/MyDrive/Colab Notebooks/Repositary/IOT_education/2.Object_Detection/mask_x_trained.pt' ./

# %%
model = torch.hub.load('yolov5')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-484192156af1> in <module>()
# ----> 1 model = torch.hub.load('yolov5')
#
# TypeError: load() missing 1 required positional argument: 'model'

# %%
import torch 
import pandas as pd 
from torchvision import models 
# resnet18의 binary classification 예제 
def CreateNetwork(): 
  net = models.resnet18() 
  return net 
  # 모델 생성
net = CreateNetwork()

# 파라미터 읽기 및 모델에 설정 
prm = torch.load("mask_x_trained.pt", map_location="cpu")
net.load_state_dict(prm) 
# 평가 모드로 설정 
net.eval()

# %%
# !python3 export.py --weights mask_x_trained.pt --include tfjs

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/Repositary
# Out:
# /content/drive/.shortcut-targets-by-id/1KU7yuHr2Pxetpf0zBqRmKviE2CE8uADM/Repositary

# %%
# !git clone https://github.com/SeojinSeojin/frontend-practice.git
# Out:
# Cloning into 'frontend-practice'...
# remote: Enumerating objects: 391, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 391 (delta 0), reused 0 (delta 0), pack-reused 390
# Receiving objects: 100% (391/391), 103.84 MiB | 12.45 MiB/s, done.
# Resolving deltas: 100% (61/61), done.
# Checking out files: 100% (259/259), done.

# %%
# !mv '/content/yolov5/mask_x_trained_web_model' '/content/drive/MyDrive/Colab Notebooks/Repositary/frontend-practice/tensorflow-js'
